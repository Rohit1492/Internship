# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#reading our data file
df=pd.read_csv('C:\\Users\\roshan.LAPTOP-IHN8RLL4\\Desktop\\rohit\\dataset1\\customer_retention_dataset.csv',engine ='python')

# %%
df.head(10)
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
# 5                      1                    3
# 6                      0                    4
# 7                      0                    4
# 8                      1                    1
# 9                      1                    3
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
#checking null value
df.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %%
#checking data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 47 columns):
# 1Gender of respondent                                                                                                                                                                                             269 non-null int64
# 2 How old are you?                                                                                                                                                                                                269 non-null int64
# 3 Which city do you shop online from?                                                                                                                                                                             269 non-null object
# ...

# %%
df.shape
# Out:
# (269, 47)

# %%
#Checking how many times you have made an online purchase in the past 1 year

df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# 1    114
# 4     63
# 5     53
# 2     29
# 3     10
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?', data=df)

plt.title('Number of purchase',fontsize=14)
plt.xlabel('purchase', fontsize=14)
plt.ylabel('count', fontsize=14)
# Out:
# Text(0, 0.5, 'count')

# %% [raw]
# we can see from above graph there are--
# 114 customer who purchased Less than 10 times in past 1 year
# 29 customer who purchased 11-20 times in past 1 year
# 10 customer who purchased 21-30 times in past 1 year
# 63 customer who purchased 31-40 times in past 1 year
# 53 customer who purchased 41 times and above in past 1 year

# %%
df.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.104118
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),linewidths=.1,cmap="Purples", annot=True, annot_kws={"size": 8})
# Out:
# <AxesSubplot:>
